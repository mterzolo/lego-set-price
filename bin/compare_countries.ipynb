# %%
import pandas as pd
import numpy as np

countries = {
    
    'AU':0.76,
    'AT':1.22,
    'BE':1.22,
    'CA':0.78,
    'CH':1.02,
    'CZ':0.048,
    'DE':1.22,
    'DN':0.12,
    'ES':1.22,
    'FI':1.22,
    'FR':1.22,
    'GB':1.4,
    'HU':0.0039,
    'IE':1.22,
    'IT':1.22,
    'LU':1.22,
    'NO':0.13,
    'NL':1.22,
    'NZ':0.71,
    'PL':0.29,
    'PT':1.22,
    'US':1
}

#load each file and append
data = pd.read_csv('..//data//US_data.csv')
data['country'] = 'US'
for country in list(countries.keys())[:-1]:
    data_2 = pd.read_csv('..//data//' + country + '_data.csv')
    data_2['country'] = country
    data = pd.concat((data, data_2))
data = data.reset_index(drop = True)
data = data[data['list_price'].notnull()]

# %%
#convert prices
data['list_price'] = data['list_price'].astype(str)
data['list_price'] = data['list_price'].apply(lambda x: ''.join(re.findall('\d+', x)))
data['list_price'] = data['list_price'].apply(lambda x: x[:-2]+'.'+x[-2:]).astype(float)
data['adj_list_price'] = data['list_price'] * data['country'].map(countries)

# %%
data[data['prod_id']==630.0]
# Out:
#       ages  list_price  num_reviews  piece_count  play_star_rating  \
# 139     4+        2.49        180.0          1.0               4.0
# 931     4+        2.99        180.0          1.0               4.0
# 1507    4+        2.49        180.0          1.0               4.0
# 2119    4+        2.99        180.0          1.0               4.0
# 2909    4+        2.90        180.0          1.0               4.0
# 3494    4+       69.00        180.0          1.0               4.0
# 4049    4+        2.49        180.0          1.0               4.0
# 4605    4+       20.00        180.0          1.0               4.0
# 5193    4+        2.49        180.0          1.0               4.0
# 5749    4+        2.95        180.0          1.0               4.0
# 6304    4+        2.49        180.0          1.0               4.0
# 6879    4+        1.99        180.0          1.0               4.0
# 7464    4+        9.90        180.0          1.0               4.0
# 7969    4+        2.49        180.0          1.0               4.0
# 8554    4+        2.49        180.0          1.0               4.0
# 9110    4+        2.49        180.0          1.0               4.0
# 9665    4+       24.00        180.0          1.0               4.0
# 10220   4+        2.49        180.0          1.0               4.0
# 10808   4+        4.99        180.0          1.0               4.0
# 11384   4+        9.99        180.0          1.0               4.0
# 11926   4+        2.49        180.0          1.0               4.0
#
#                  prod_desc  prod_id  \
# 139    Everyone needs one!    630.0
# 931    Everyone needs one!    630.0
# 1507   Everyone needs one!    630.0
# 2119   Everyone needs one!    630.0
# 2909   Everyone needs one!    630.0
# 3494   Everyone needs one!    630.0
# 4049   Everyone needs one!    630.0
# 4605   Everyone needs one!    630.0
# 5193   Everyone needs one!    630.0
# 5749   Everyone needs one!    630.0
# 6304   Everyone needs one!    630.0
# 6879   Everyone needs one!    630.0
# 7464   Everyone needs one!    630.0
# 7969   Everyone needs one!    630.0
# 8554   Everyone needs one!    630.0
# 9110   Everyone needs one!    630.0
# 9665   Everyone needs one!    630.0
# 10220  Everyone needs one!    630.0
# 10808  Everyone needs one!    630.0
# 11384  Everyone needs one!    630.0
# 11926  Everyone needs one!    630.0
#
#                                           prod_long_desc review_difficulty  \
# 139    This tool makes it a snap to pull those small ...         Very Easy
# 931    This tool makes it a snap to pull those small ...         Very Easy
# 1507   This tool makes it a snap to pull those small ...         Very Easy
# 2119   This tool makes it a snap to pull those small ...         Very Easy
# 2909   This tool makes it a snap to pull those small ...         Very Easy
# 3494   This tool makes it a snap to pull those small ...         Very Easy
# 4049   This tool makes it a snap to pull those small ...         Very Easy
# 4605   This tool makes it a snap to pull those small ...         Very Easy
# 5193   This tool makes it a snap to pull those small ...         Very Easy
# 5749   This tool makes it a snap to pull those small ...         Very Easy
# 6304   This tool makes it a snap to pull those small ...         Very Easy
# 6879   This tool makes it a snap to pull those small ...         Very Easy
# 7464   This tool makes it a snap to pull those small ...         Very Easy
# 7969   This tool makes it a snap to pull those small ...         Very Easy
# 8554   This tool makes it a snap to pull those small ...         Very Easy
# 9110   This tool makes it a snap to pull those small ...         Very Easy
# 9665   This tool makes it a snap to pull those small ...         Very Easy
# 10220  This tool makes it a snap to pull those small ...         Very Easy
# 10808  This tool makes it a snap to pull those small ...         Very Easy
# 11384  This tool makes it a snap to pull those small ...         Very Easy
# 11926  This tool makes it a snap to pull those small ...         Very Easy
#
#               set_name  star_rating theme_name  val_star_rating country  \
# 139    Brick Separator          4.8    Classic              4.6      US
# 931    Brick Separator          4.8    Classic              4.6      AU
# 1507   Brick Separator          4.8    Classic              4.6      BE
# 2119   Brick Separator          4.8    Classic              4.6      CA
# 2909   Brick Separator          4.8    Classic              4.6      CH
# 3494   Brick Separator          4.8    Classic              4.6      CZ
# 4049   Brick Separator          4.8    Classic              4.6      DE
# 4605   Brick Separator          4.8    Classic              4.6      DN
# 5193   Brick Separator          4.8    Classic              4.6      ES
# 5749   Brick Separator          4.8    Classic              4.6      FI
# 6304   Brick Separator          4.8    Classic              4.6      FR
# 6879   Brick Separator          4.8    Classic              4.6      GB
# 7464   Brick Separator          4.8    Classic              4.6      HU
# 7969   Brick Separator          4.8    Classic              4.6      IE
# 8554   Brick Separator          4.8    Classic              4.6      IT
# 9110   Brick Separator          4.8    Classic              4.6      LU
# 9665   Brick Separator          4.8    Classic              4.6      NO
# 10220  Brick Separator          4.8    Classic              4.6      NL
# 10808  Brick Separator          4.8    Classic              4.6      NZ
# 11384  Brick Separator          4.8    Classic              4.6      PL
# 11926  Brick Separator          4.8    Classic              4.6      PT
#
#        adj_list_price
# 139            2.4900
# 931            2.2724
# 1507           3.0378
# 2119           2.3322
# 2909           2.9580
# 3494           3.3120
# 4049           3.0378
# 4605           2.4000
# 5193           3.0378
# 5749           3.5990
# 6304           3.0378
# 6879           2.7860
# 7464           0.3861
# 7969           3.0378
# 8554           3.0378
# 9110           3.0378
# 9665           3.1200
# 10220          3.0378
# 10808          3.5429
# 11384          2.8971
# 11926          3.0378

# %%
us_items = data[data['country']=='US']['prod_id'].unique()
not_us = data[data['country']!='US']
not_us[~not_us['prod_id'].isin(us_items)].drop_duplicates('prod_id')
# Out:
#      ages  list_price  num_reviews  piece_count  play_star_rating  \
# 489   NaN         NaN          NaN          NaN               NaN
# 82   4-99   39,90 CHF          2.0        900.0               3.5
# 85   4-99   29,90 CHF          2.0        502.0               5.0
# 86   4-99   29,90 CHF          NaN        442.0               NaN
# 104  9-14   69,90 CHF         23.0        792.0               4.7
# 136   12+   79,90 CHF        142.0        898.0               3.9
# 139  7-14  119,00 CHF          6.0          NaN               4.5
# 162  7-14   34,90 CHF          7.0        115.0               4.4
# 163  7-14   34,90 CHF          4.0        102.0               4.8
# 164  7-14   29,90 CHF          4.0        119.0               5.0
# 165  7-14   29,90 CHF          3.0         96.0               5.0
# 171  7-14   17,90 CHF          1.0         57.0               5.0
# 173  7-14   17,90 CHF          3.0         73.0               3.7
# 174  7-14   17,90 CHF          2.0         58.0               4.5
# 175  7-14   17,90 CHF          2.0         52.0               3.5
# 176  7-14   17,90 CHF          8.0         45.0               3.6
# 179  7-14   34,90 CHF         13.0         85.0               4.1
# 180  7-14   17,90 CHF          3.0         55.0               4.0
# 181  7-14   17,90 CHF          7.0         38.0               4.1
# 218   2-5   39,90 CHF          NaN        120.0               NaN
# 236  1½-3   24,90 CHF          NaN         80.0               NaN
# 436   14+  229,00 CHF         61.0       2028.0               4.6
# 484  8-14   59,90 CHF         24.0        358.0               4.7
# 141  7-14   799,00 kr          5.0          NaN               4.0
# 368    8+     17,50 €         13.0          1.0               3.8
#
#                                              prod_desc  prod_id  \
# 489                                                NaN      NaN
# 82       Imagine and create with LEGO® Classic bricks!  10704.0
# 85        Create your ideas with LEGO® Classic bricks!  10703.0
# 86     Create a world in motion with Bricks on a Roll!  10715.0
# 104  Head for sunnier climes with the Vacation Geta...  31052.0
# 136  Enjoy the holiday season with the Winter Toy S...  10249.0
# 139  With LEGO® Dimensions™, you're gonna need a bi...  71170.0
# 162  Fight ghosts with the LEGO® DIMENSIONS™ The Gh...  71228.0
# 163  Help Finn battle foes through an Adventure Tim...  71245.0
# 164  Bring the Wizarding World to life with Harry a...  71247.0
# 165  Explore the Land of Ooo with Jake and Lumpy Sp...  71246.0
# 171  Fight crime in the night with the bold and bra...  71344.0
# 173  Conquer the bad guys with action hero B.A. Bar...  71251.0
# 174        Become one with Spinjitzu Master Sensei Wu!  71234.0
# 175  Dig your way through the multiverse as DC Comi...  71240.0
# 176  Perfect your Spinjitzu skills with LEGO® NINJA...  71217.0
# 179  Puzzle through LEGO® DIMENSIONS™ Portal® 2 wit...  71203.0
# 180  Carry on your crime-fighting adventure with Mi...  71286.0
# 181  Unleash magical powers with the Wicked Witch™ ...  71221.0
# 218  Imagine and create with this big box of colorf...  10854.0
# 236  Develop creativity and building skills with a ...  10848.0
# 436  Join the Ninja at the beautiful Temple of Airj...  70751.0
# 484                     Prepare the A-wing for action!  75175.0
# 141  With LEGO® Dimensions™, you're gonna need a bi...  71172.0
# 368                            Your robot's "fingers!"   9843.0
#
#                                         prod_long_desc review_difficulty  \
# 489                                                NaN               NaN
# 82   Unleash a world of open-ended creativity and i...               NaN
# 85   Unleash a world of open-ended creativity and i...           Average
# 86   Put your LEGO® creations on wheels with this e...               NaN
# 104  Explore exciting destinations with this awesom...           Average
# 136  Welcome to the Winter Toy Shop! The holiday se...           Average
# 139  The LEGO® DIMENSIONS™ Starter Pack has everyth...           Average
# 162  Spookify your LEGO® DIMENSIONS™ experience wit...              Easy
# 163  Enjoy more LEGO® DIMENSIONS™ gameplay with the...         Very Easy
# 164  Enhance your LEGO® DIMENSIONS™ experience with...              Easy
# 165  Enhance your LEGO® DIMENSIONS™ experience with...              Easy
# 171  Join Excalibur Batman™ from THE LEGO® BATMAN M...           Average
# 173  Enhance your LEGO® DIMENSIONS™ experience with...              Easy
# 174  Bolster your LEGO® DIMENSIONS™ gameplay with t...              Easy
# 175  Broaden your LEGO® DIMENSIONS™ gameplay with t...              Easy
# 176  Bolster your LEGO® DIMENSIONS™ gameplay with t...              Easy
# 179  Take your LEGO® DIMENSIONS™ gameplay to the ne...           Average
# 180  Help save the LEGO® DIMENSIONS™ multiverse wit...              Easy
# 181  Add a touch of magic to your LEGO® DIMENSIONS™...              Easy
# 218  Open up a world of creativity with this huge s...               NaN
# 236  Fire your toddler’s imagination with this grea...               NaN
# 436  Enjoy the ultimate LEGO® NINJAGO™ building exp...       Challenging
# 484  Launch into LEGO® Star Wars missions with the ...              Easy
# 141  The LEGO® DIMENSIONS™ Starter Pack has everyth...           Average
# 368  The Touch Sensor reacts to touch and release, ...         Very Easy
#
#                          set_name  star_rating      theme_name  \
# 489                           NaN          NaN             NaN
# 82                   Creative Box          4.5         Classic
# 85           Creative Builder Box          4.0         Classic
# 86               Bricks on a Roll          NaN         Classic
# 104             Vacation Getaways          4.9  Creator 3-in-1
# 136               Winter Toy Shop          3.8  Creator Expert
# 139   Starter Pack PLAYSTATION® 3          4.2     DIMENSIONS™
# 162  The Ghostbusters™ Level Pack          4.7     DIMENSIONS™
# 163    Adventure Time™ Level Pack          4.5     DIMENSIONS™
# 164       Harry Potter™ Team Pack          5.0     DIMENSIONS™
# 165     Adventure Time™ Team Pack          4.7     DIMENSIONS™
# 171    Excalibur Batman™ Fun Pack          5.0     DIMENSIONS™
# 173              A-Team™ Fun Pack          4.3     DIMENSIONS™
# 174            Sensei Wu Fun Pack          4.5     DIMENSIONS™
# 175                Bane™ Fun Pack          4.0     DIMENSIONS™
# 176                 Zane Fun Pack          4.0     DIMENSIONS™
# 179          Portal® 2 Level Pack          4.1     DIMENSIONS™
# 180        Knight Rider™ Fun Pack          4.0     DIMENSIONS™
# 181        Wicked Witch™ Fun Pack          4.3     DIMENSIONS™
# 218     LEGO® DUPLO® Creative Box          NaN          DUPLO®
# 236               My First Bricks          NaN          DUPLO®
# 436            Temple of Airjitzu          4.8        NINJAGO®
# 484           A-Wing Starfighter™          4.6      Star Wars™
# 141        Starter Pack Xbox One™          4.4     DIMENSIONS™
# 368                  Touch Sensor          3.8     MINDSTORMS®
#
#      val_star_rating country
# 489              NaN      CA
# 82               4.5      CH
# 85               4.0      CH
# 86               NaN      CH
# 104              4.3      CH
# 136              3.7      CH
# 139              3.8      CH
# 162              4.3      CH
# 163              4.0      CH
# 164              4.3      CH
# 165              4.0      CH
# 171              5.0      CH
# 173              4.0      CH
# 174              4.0      CH
# 175              3.5      CH
# 176              3.5      CH
# 179              3.9      CH
# 180              3.7      CH
# 181              3.7      CH
# 218              NaN      CH
# 236              NaN      CH
# 436              4.3      CH
# 484              3.7      CH
# 141              4.0      DN
# 368              3.5      FR
